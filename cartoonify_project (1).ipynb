# %% [markdown]
# # **Cartoonify an Image**

# %% [markdown]
# **Importing Libraries**

# %%
import cv2 #for dealing with images
import numpy as np
# required bcz used Google Colab
from google.colab.patches import cv2_imshow
from google.colab import files

# %% [markdown]
# **Uploading images for cartoonifying process**

# %%
def read_file(filename):
  img = cv2.imread(filename)
  cv2_imshow(img)
  return img

# %%
uploaded = files.upload()
filename = next(iter(uploaded))
img = read_file(filename)
# Out:
#      <input type="file" id="files-a9bc4b17-5a39-4a88-a3cd-0c7d1b6b6dd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9bc4b17-5a39-4a88-a3cd-0c7d1b6b6dd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cartoon.jpg to cartoon.jpg
# <PIL.Image.Image image mode=RGB size=258x225 at 0x7F993A1A5A90>

# %% [markdown]
# **Transforming an image to grayscale image**

# %% [markdown]
# **Smoothening a grayscale image**

# %% [markdown]
# **Retrieving the edges of an image**

# %%
def edge_mask(img, line_size, blur_value):
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  gray_blur = cv2.medianBlur(gray, blur_value)
  edges = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, line_size, blur_value)
  return edges

# %%
line_size = 7
blur_value = 7
edges = edge_mask(img, line_size, blur_value)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=258x225 at 0x7F992B3D8750>

# %% [markdown]
# **Giving a Cartoon Effect**

# %%
def color_quantization(img, k):
# Transform the image
  data = np.float32(img).reshape((-1, 3))

# Determine criteria
  criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 20, 0.001)

# Implementing K-Means
  ret, label, center = cv2.kmeans(data, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
  center = np.uint8(center)
  result = center[label.flatten()]
  result = result.reshape(img.shape)
  return result

# %%
total_color = 9
img = color_quantization(img, total_color)

# %%
blurred = cv2.bilateralFilter(img, d=7, sigmaColor=200,sigmaSpace=200)

# %%
cartoon = cv2.bitwise_and(blurred, blurred, mask=edges)

# %%
cv2_imshow(cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=258x225 at 0x7F992AB78E10>
